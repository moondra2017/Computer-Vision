# %%
import hashlib
from scipy.misc import imread, imresize, imshow
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import numpy as np

# %% [markdown]
# ### Removing duplicate images using hashing

# %%
def file_hash(filepath):
    with open(filepath, 'rb') as f:
        return md5(f.read()).hexdigest()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Moondra\\PYTHON STUFF\\Recent Python Stuff'

# %%
os.chdir(r'C:\Users\Moondra\Desktop\DATA\IMAGE_2')
os.getcwd()
# Out:
# 'C:\\Users\\Moondra\\Desktop\\DATA\\IMAGE_2'

# %%
files_list = os.listdir()
print(len(files_list))
`
# Out:
# 46

# %%
import hashlib, os
duplicates = []
hash_keys = dict()
for index, filename in  enumerate(os.listdir('.')):  #listdir('.') = current directory
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys: 
            hash_keys[filehash] = index
        else:
            duplicates.append((index,hash_keys[filehash]))

# %%
duplicates
# Out:
# [(1, 0), (40, 39), (45, 44)]

# %%
for file_indexes in duplicates[:30]:
    try:
    
        plt.subplot(121),plt.imshow(imread(files_list[file_indexes[1]]))
        plt.title(file_indexes[1]), plt.xticks([]), plt.yticks([])

        plt.subplot(122),plt.imshow(imread(files_list[file_indexes[0]]))
        plt.title(str(file_indexes[0]) + ' duplicate'), plt.xticks([]), plt.yticks([])
        plt.show()
    
    except OSError as e:
        continue

# %% [markdown]
# #### Delete Files After Printing

# %%
for index in duplicates:
    os.remove(files_list[index[0]])
